# %%
import pandas as pd 
import numpy as np

# # Read dictionary pkl file
import pickle
with open('visual_datasets_03312024.pkl', 'rb') as fp:
    visual_datasets = pickle.load(fp)

# %%
visual_datasets[2012]['shap_values']
# Out:
#       Obesity(Percentage)  FarmersMarket(Rate)  \
# 0                0.105654            -0.249414
# 1               -0.166057             0.037691
# 2               -0.147322            -0.220060
# 3               -0.174660            -0.145973
# 4               -0.125595            -0.004337
# ...                   ...                  ...
# 3136             1.403314             0.109773
# 3137             1.818355            -0.188501
# 3138             1.437316            -0.184774
# 3139             1.663410            -0.177765
# 3140             1.914068            -0.095305
#
#       FastFoodRestaurants:Rateper1000Population(Rate)  \
# 0                                            0.132534
# 1                                           -0.021005
# 2                                            0.003721
# 3                                           -0.006313
# 4                                           -0.006543
# ...                                               ...
# ...

# %%
visual_datasets[2012]['processed_data']
# Out:
#       Obesity(Percentage)  FarmersMarket(Rate)  \
# 0                    28.0             0.259046
# 1                    18.4             0.052374
# 2                    19.1             0.094867
# 3                    19.7             0.092323
# 4                    18.3             0.068756
# ...                   ...                  ...
# 3136                 38.5             0.026103
# 3137                 40.3             0.157348
# 3138                 38.9             0.242925
# 3139                 36.6             0.282300
# 3140                 39.9             0.100261
#
#       FastFoodRestaurants:Rateper1000Population(Rate)  \
# 0                                            0.894868
# 1                                            0.418877
# 2                                            0.754945
# 3                                            0.412858
# 4                                            0.362713
# ...                                               ...
# ...
